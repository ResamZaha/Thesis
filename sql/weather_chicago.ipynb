# %%
import time
import pandas as pd
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, create_engine, Float
from sqlalchemy.orm import scoped_session, sessionmaker
from sqlalchemy import Table
from sqlalchemy import create_engine, text
import os

# %%
#create connection to database
username = 'postgres'
password = '1234'
host = 'localhost'
port = '5432'
database = 'thesis'

address = 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host, port, database)
print(address)
engine = create_engine(address, echo=False)
# Out:
# postgresql://postgres:1234@localhost:5432/thesis

# %% [markdown]
# <h1><b>Chicago</h1></b>

# %% [markdown]
# <h1><b>Weather</h1></b>

# %% [markdown]
# <h1><b>Start</h1></b>

# %% [markdown]
# Columns

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT column_name FROM information_schema.columns WHERE table_name = 'sf_weather';"))
    for row in rs:
        print(row)
        c = c + 1
print("total columns: ", c)
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
# Out:
# ('Unnamed: 0',)
# ('expire_time_gmt',)
# ('valid_time_gmt',)
# ('temp',)
# ('wspd',)
# ('max_temp',)
# ('min_temp',)
# ('heat_index',)
# ('rh',)
# ('pressure',)
# ('vis',)
# ('wc',)
# ('wdir',)
# ('wx_phrase',)
# ('valid_date_time',)
# ('expire_date_time',)
# total columns:  16
# Execution Time: 0.06 seconds

# %% [markdown]
# <h3><b> Phrase Types without Pipeline </h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT DISTINCT wx_phrase FROM chicago_weather;"))
    for row in rs:
        print(row)
        c += 1
print("Number of Weather Description = ",c)
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
# Out:
# Number of Weather Description =  165352
# Execution Time: 0.29 seconds

# %%
del rs

# %% [markdown]
# <h3><b> Phrase Types using Pipeline </h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT wx_phrase FROM chicago_weather GROUP BY wx_phrase;"))
    for row in rs:
        print(row)
        c += 1
print("Number of Weather Description = ",c)
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
# Out:
# ('Blowing Snow',)
# ('Blowing Snow / Windy',)
# ('Cloudy',)
# ('Cloudy / Windy',)
# ('Drizzle',)
# ('Drizzle and Fog',)
# ('Fair',)
# ('Fair / Windy',)
# ('Fog',)
# ('Fog / Windy',)
# ('Funnel Cloud',)
# ('Haze',)
# ('Haze / Windy',)
# ('Heavy Rain',)
# ('Heavy Rain / Windy',)
# ('Heavy Snow',)
# ('Heavy Snow / Windy',)
# ('Heavy T-Storm',)
# ('Heavy T-Storm / Windy',)
# ('Light Drizzle',)
# ('Light Drizzle / Windy',)
# ('Light Freezing Drizzle',)
# ('Light Freezing Rain',)
# ('Light Rain',)
# ('Light Rain / Windy',)
# ('Light Rain with Thunder',)
# ('Light Sleet',)
# ('Light Sleet / Windy',)
# ('Light Snow',)
# ('Light Snow / Freezing Rain',)
# ('Light Snow / Windy',)
# ('Light Snow and Sleet',)
# ('Light Snow and Sleet / Windy',)
# ('Mostly Cloudy',)
# ('Mostly Cloudy / Windy',)
# ('Partly Cloudy',)
# ('Partly Cloudy / Windy',)
# ('Patches of Fog',)
# ('Rain',)
# ('Rain / Freezing Rain',)
# ('Rain / Windy',)
# ('Rain and Sleet',)
# ('Rain and Snow',)
# ('Rain and Snow / Windy',)
# ...

# %%
del rs

# %% [markdown]
# <h3><b>4.2.5 Average Temprature</h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT AVG(temp) AS average_temperature FROM chicago_weather;"))
    for row in rs:
        print(row)
        c += 1
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.3f} seconds".format(execution_time))
# Out:
# (10.897020225413,)
# Execution Time: 0.020 seconds

# %%
del rs

# %% [markdown]
# <h3><b>  4.2.4 Max Temprature </h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT MAX(temp) AS max_temperature FROM chicago_weather;"))
    for row in rs:
        print(row)
        c += 1
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.3f} seconds".format(execution_time))
# Out:
# (40.0,)
# Execution Time: 0.065 seconds

# %%
del rs

# %% [markdown]
# <h3><b> Min Temprature </h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT MIN(temp) AS min_temperature FROM chicago_weather;"))
    for row in rs:
        print(row)
        c += 1
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.3f} seconds".format(execution_time))
# Out:
# (-29.0,)
# Execution Time: 0.018 seconds

# %%
del rs

# %% [markdown]
# <h3><b>Max Temp Per Year </h3></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT EXTRACT(YEAR FROM TO_TIMESTAMP(valid_date_time, 'DD/MM/YYYY HH24:MI:SS')) AS year, MAX(temp) AS max_temperature FROM chicago_weather GROUP BY EXTRACT(YEAR FROM TO_TIMESTAMP(valid_date_time, 'DD/MM/YYYY HH24:MI:SS'));"))
    for row in rs:
        print(row)
        c += 1
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
# Out:
# (Decimal('2007'), 34.0)
# (Decimal('2010'), 34.0)
# (Decimal('2009'), 34.0)
# (Decimal('2008'), 34.0)
# (Decimal('2014'), 34.0)
# (Decimal('2013'), 36.0)
# (Decimal('2016'), 34.0)
# (Decimal('2015'), 34.0)
# (Decimal('2012'), 39.0)
# (Decimal('2018'), 36.0)
# (Decimal('2020'), 35.0)
# (Decimal('2005'), 40.0)
# (Decimal('2011'), 38.0)
# (Decimal('2019'), 36.0)
# (Decimal('2004'), 33.0)
# (Decimal('2006'), 37.0)
# (Decimal('2022'), 38.0)
# (Decimal('2017'), 35.0)
# (Decimal('2021'), 35.0)
# Execution Time: 0.17 seconds

# %%
del rs

# %% [markdown]
# <h1><b> 4.1.1 Count Rainy Days </h1></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
c = 0
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT * FROM  chicago_weather WHERE wx_phrase ILIKE '%Rain%';"))
    for row in rs:
        print(row)
        c += 1
print("Total Cases = " , c)
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
#{"wx_phrase": {"$regex": "Rain", "$options": "i"}}
# .113 seconds
# Out:
# (104050, 1395226260, 1395219060, 7.0, 'Light Rain', 7.0, 90.0, 980.43, 9.0, 4.0, 200.0, 15.0, None, None, '19/03/2014 17:00:00', '19/03/2014 15:00:00')
# (104051, 1395229860, 1395222660, 7.0, 'Light Rain', 7.0, 93.0, 979.77, 8.0, 4.0, 170.0, 9.0, None, None, '19/03/2014 18:00:00', '19/03/2014 16:00:00')
# (104052, 1395231660, 1395224460, 7.0, 'Light Rain', 7.0, 93.0, 979.44, 8.0, 4.0, 170.0, 9.0, None, None, '19/03/2014 18:00:00', '19/03/2014 16:00:00')
# (104053, 1395233460, 1395226260, 7.0, 'Light Rain', 7.0, 96.0, 979.44, 8.0, 4.0, 160.0, 13.0, None, None, '19/03/2014 19:00:00', '19/03/2014 17:00:00')
# (104054, 1395236040, 1395228840, 7.0, 'Rain', 7.0, 93.0, 979.44, 6.0, 4.0, 190.0, 17.0, None, None, '19/03/2014 20:00:00', '19/03/2014 18:00:00')
# (104055, 1395237060, 1395229860, 7.0, 'Light Rain', 7.0, 96.0, 979.44, 6.0, 4.0, 200.0, 13.0, None, None, '19/03/2014 20:00:00', '19/03/2014 18:00:00')
# ...

# %%
del rs

# %% [markdown]
# <h1><b>Wind Direction Distribution </h1></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
# SELECT * FROM weather LIMIT 10;
with engine.connect() as con:
    rs = con.execute(text("SELECT \"wdir\", COUNT(*) AS case_count FROM chicago_weather GROUP BY \"wdir\" ORDER BY wdir DESC;"))
    for row in rs:
        print(row)

# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.2f} seconds".format(execution_time))
# Out:
# (None, 12837)
# (360.0, 3892)
# (350.0, 3722)
# (340.0, 3483)
# (330.0, 4745)
# (320.0, 4668)
# (310.0, 4815)
# (300.0, 5412)
# (290.0, 5792)
# (280.0, 5968)
# (270.0, 6832)
# (260.0, 6079)
# (250.0, 6774)
# (240.0, 6660)
# (230.0, 5725)
# (220.0, 6438)
# (210.0, 8795)
# (200.0, 9216)
# (190.0, 7328)
# (180.0, 6148)
# (170.0, 5155)
# (160.0, 3678)
# (150.0, 2868)
# (140.0, 3199)
# (130.0, 2748)
# (120.0, 2851)
# (110.0, 3142)
# (100.0, 4307)
# (90.0, 4798)
# (80.0, 4648)
# (70.0, 4188)
# (60.0, 4277)
# (50.0, 3804)
# (40.0, 4193)
# (30.0, 5464)
# (20.0, 5010)
# (10.0, 4672)
# Execution Time: 0.03 seconds

# %%
del rs

# %% [markdown]
# <h1><b> 4.1.2 In A Range Check</h1></b>

# %%
# Record the start time
start_time = time.time()

# query in chicago_weather crime database
from sqlalchemy import text
# SELECT * FROM weather LIMIT 10;
c = 0
with engine.connect() as con:
    rs = con.execute(text("SELECT * FROM chicago_weather WHERE pressure > 1000.00 AND pressure < 1001.00;"))
    for row in rs:
        print(row)
        c = c+1
print("Total Cases = ", c)
# Record the end time
end_time = time.time()
execution_time = end_time - start_time
print("Execution Time: {:.3f} seconds".format(execution_time))
# Out:
# (11, 1072983180, 1072975980, 3.0, 'Cloudy', 3.0, 65.0, 1000.08, 16.0, -1.0, 170.0, 19.0, None, None, '02/01/2004 01:00:00', '01/01/2004 23:00:00')
# (147, 1073325180, 1073317980, -5.0, 'Mostly Cloudy', -5.0, 81.0, 1000.96, 16.0, -12.0, 330.0, 24.0, None, None, '06/01/2004 00:00:00', '05/01/2004 22:00:00')
# (149, 1073332380, 1073325180, -4.0, 'Cloudy', -4.0, 78.0, 1000.76, 16.0, -11.0, 330.0, 22.0, -3.0, -5.0, '06/01/2004 02:00:00', '06/01/2004 00:00:00')
# (150, 1073335980, 1073328780, -4.0, 'Mostly Cloudy', -4.0, 75.0, 1000.66, 16.0, -10.0, 320.0, 19.0, None, None, '06/01/2004 03:00:00', '06/01/2004 01:00:00')
# (151, 1073339580, 1073332380, -3.0, 'Cloudy', -3.0, 69.0, 1000.76, 16.0, -10.0, 310.0, 22.0, None, None, '06/01/2004 04:00:00', '06/01/2004 02:00:00')
# (229, 1073614800, 1073607600, -1.0, 'Cloudy', -1.0, 69.0, 1000.96, 16.0, -1.0, 110.0, 6.0, None, None, '09/01/2004 08:00:00', '09/01/2004 06:00:00')
# ...

# %%
del rs

# %% [markdown]
# <h1><b> Complex Queries </b> <h1>

# %% [markdown]
# <h3> total sum of temperatures and pressures for each distinct weather phrase (wx_phrase) </h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    wx_phrase,
    SUM(temp) AS total_temp,
    SUM(pressure) AS total_pressure
FROM chicago_weather
GROUP BY wx_phrase
ORDER BY wx_phrase;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
# Out:
#                   wx_phrase  total_temp  total_pressure
# 0              Blowing Snow      -215.0        10876.14
# 1      Blowing Snow / Windy      -632.0        33614.80
# 2                    Cloudy    567051.0     66652048.02
# 3            Cloudy / Windy     21287.0      3477722.62
# 4                   Drizzle        86.0         7937.49
# ..                      ...         ...             ...
# 58                  Tornado        24.0          989.04
# 59  Widespread Dust / Windy        28.0          980.10
# 60               Wintry Mix       157.0       371247.08
# 61       Wintry Mix / Windy        27.0        31669.85
# 62                     None        34.0         3976.91
#
# [63 rows x 3 columns]
# Execution Time: 0.12 seconds

# %% [markdown]
# <h3> Daily Data</h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    TO_DATE(valid_date_time, 'DD/MM/YYYY') AS day,
    AVG(temp) AS avg_temp,
    SUM(wspd) AS total_wspd,
    MAX(vis) AS max_visibility,
    COUNT(DISTINCT wx_phrase) AS distinct_weather_conditions
FROM chicago_weather
GROUP BY day
ORDER BY day;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
# Out:
#              day   avg_temp  total_wspd  max_visibility  \
# 0     2004-01-01   0.000000       125.0            16.0
# 1     2004-01-02   7.027778       489.0            16.0
# 2     2004-01-03  11.516129       651.0            16.0
# 3     2004-01-04   1.000000       742.0            16.0
# 4     2004-01-05  -1.852941       875.0            16.0
# ...          ...        ...         ...             ...
# 6935  2022-12-27  -9.000000       279.0            16.0
# 6936  2022-12-28  -3.320000       659.0            16.0
# 6937  2022-12-29   7.541667       690.0            16.0
# 6938  2022-12-30  11.592593       655.0            16.0
# 6939  2022-12-31   2.461538       125.0            16.0
#
#       distinct_weather_conditions
# 0                               2
# 1                               3
# 2                               6
# 3                               4
# 4                               3
# ...                           ...
# 6935                            5
# ...

# %% [markdown]
# <h1> <b> addition </b></h1>

# %% [markdown]
# <h1> <b> subtraction </b></h1>

# %% [markdown]
# <h1> <b> comparing </b></h1>

# %% [markdown]
# <h3> 4.1.3 Selecting records with temperature differences within a specified range and wind speed above a certain threshold </h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    "Unnamed: 0",
    "expire_time_gmt",
    "valid_time_gmt",
    "temp",
    "wspd",
    "wx_phrase",
    "valid_date_time",
    "expire_date_time",
    "max_temp" - "min_temp" AS temperature_difference,
    CASE 
        WHEN "wspd" > 20 THEN 'High wind'
        ELSE 'Low wind'
    END AS wind_speed_category
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
#.144 seconds
#.211 seconds

#project
"""{"_id": 0,"Unnamed: 0": 1, "expire_time_gmt": 1,
            "valid_time_gmt": 1,
            "temp": 1,
            "wspd": 1,
            "wx_phrase": 1,
            "valid_date_time": 1,
            "expire_date_time": 1,"temperature_difference": {"$subtract": ["$max_temp", "$min_temp"]}, "wind_speed_category": {"$cond": {"if": {"$gt": ["$wspd", 20]}, "then": "High wind", "else": "Low wind"}}}"""
# Out:
#         Unnamed: 0  expire_time_gmt  valid_time_gmt  temp  wspd  \
# 0                0       1072943580      1072936380  -1.0   6.0
# 1                1       1072947180      1072939980  -1.0   9.0
# 2                2       1072950780      1072943580  -1.0   NaN
# 3                3       1072954380      1072947180  -1.0   7.0
# 4                4       1072957980      1072950780  -1.0   6.0
# ...            ...              ...             ...   ...   ...
# 194326      194326       1672458780      1672451580   2.0   6.0
# 194327      194327       1672462380      1672455180   2.0   7.0
# 194328      194328       1672465980      1672458780   1.0  11.0
# 194329      194329       1672469580      1672462380   1.0  11.0
# 194330      194330       1672473180      1672465980  -1.0   0.0
#
#             wx_phrase      valid_date_time     expire_date_time  \
# 0       Mostly Cloudy  01/01/2004 12:00:00  01/01/2004 14:00:00
# 1       Mostly Cloudy  01/01/2004 13:00:00  01/01/2004 15:00:00
# ...

# %% [markdown]
# <h3> 4.1.4 Identifying records where visibility is within a certain range and the temperature is below freezing </h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    "Unnamed: 0",
    "expire_date_time",
    "expire_time_gmt",
    "valid_date_time",
    "valid_time_gmt",
    "vis",
    "wx_phrase",
        CASE 
        WHEN "wdir" BETWEEN 0 AND 180 THEN 'Easterly Wind'
        ELSE 'Westerly Wind'
    END AS wind_direction,
    "temp",
    CASE 
        WHEN "temp" < 0 THEN 'Below freezing'
        ELSE 'Above freezing'
    END AS temperature_status
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
#.137 seconds
# Out:
#         Unnamed: 0     expire_date_time  expire_time_gmt      valid_date_time  \
# 0                0  01/01/2004 14:00:00       1072943580  01/01/2004 12:00:00
# 1                1  01/01/2004 15:00:00       1072947180  01/01/2004 13:00:00
# 2                2  01/01/2004 16:00:00       1072950780  01/01/2004 14:00:00
# 3                3  01/01/2004 17:00:00       1072954380  01/01/2004 15:00:00
# 4                4  01/01/2004 18:00:00       1072957980  01/01/2004 16:00:00
# ...            ...                  ...              ...                  ...
# 194326      194326  31/12/2022 10:00:00       1672458780  31/12/2022 08:00:00
# 194327      194327  31/12/2022 11:00:00       1672462380  31/12/2022 09:00:00
# 194328      194328  31/12/2022 12:00:00       1672465980  31/12/2022 10:00:00
# 194329      194329  31/12/2022 13:00:00       1672469580  31/12/2022 11:00:00
# 194330      194330  31/12/2022 14:00:00       1672473180  31/12/2022 12:00:00
#
# ...

# %% [markdown]
# <h3> 4.1.5 Comparing temperature differences with visibility ranges to classify weather severity</h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    "Unnamed: 0",
    "valid_time_gmt",
    "temp" - "wc" AS realfeel_difference,
    "vis",
    CASE
        WHEN "vis" < 5 THEN 'Low Visibility'
        WHEN "vis" BETWEEN 5 AND 15 THEN 'Moderate Visibility'
        ELSE 'High Visibility'
    END AS visibility_status,
    CASE
        WHEN "temp" - "wc" > 20 THEN 'Significant Wind Chill Effect'
        ELSE 'Negligible Wind Chill Effect'
    END AS wind_chill_effect,
    "wx_phrase",
    "valid_date_time"
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
#0.139 seconds

#{"_id": 0,"wind_chill_effect": {"$cond": [{"$gt": [{"$subtract": ["$temp", "$wc"]}, 20]}, "Significant Wind Chill Effect", "Negligible Wind Chill Effect"]}, "wx_phrase": 1, "valid_date_time": 1, "Unnamed: 0": 1, "valid_time_gmt": 1, "temp": 1, "vis": 1, "realfeel_difference": {"$subtract": ["$temp", "$wc"]}, "visibility_status": {"$cond": [{"$lt": ["$vis", 5]}, "Low Visibility", {"$cond": [{"$and": [{"$gte": ["$vis", 5]}, {"$lte": ["$vis", 15]}]}, "Moderate Visibility", "High Visibility"]}]},"wind_chill_effect":{"$cond":{"if":{"$gt":[{"$subtract":["$temp","$wc"]},20]},"then":"Significant Wind Chill Effect","else":"Negligible Wind Chill Effect"}},"wx_phrase":1,"valid_date_time":1 }
# Out:
#         Unnamed: 0  valid_time_gmt  realfeel_difference   vis  \
# 0                0      1072936380                  0.0  16.0
# 1                1      1072939980                  3.0  16.0
# 2                2      1072943580                  0.0  16.0
# 3                3      1072947180                  2.0  16.0
# 4                4      1072950780                  0.0  16.0
# ...            ...             ...                  ...   ...
# 194326      194326      1672451580                  0.0  14.0
# 194327      194327      1672455180                  3.0  14.0
# 194328      194328      1672458780                  4.0  16.0
# 194329      194329      1672462380                  4.0  16.0
# 194330      194330      1672465980                  0.0  16.0
#
#           visibility_status             wind_chill_effect      wx_phrase  \
# 0           High Visibility  Negligible Wind Chill Effect  Mostly Cloudy
# ...

# %% [markdown]
# <h3> 4.1.6 Calculating wind direction variance and assigning weather status based on wind chill </h3>

# %%
start_time = time.time()

# SQL query with SUM
query = text("""
SELECT 
    "Unnamed: 0",
    "valid_time_gmt",
    "wdir" + 180 AS opposite_wdir,
    "wc" - 5 AS reduced_wind_chill,
    "temp" * "wspd" AS wind_temperature_factor,
    ("temp" + "wspd") / 2 AS comfort_index,
    CASE
        WHEN "temp" > 85 THEN 'Too Hot'
        WHEN "temp" < 32 THEN 'Too Cold'
        ELSE 'Comfortable'
    END AS comfort_status,
    CASE
        WHEN "wc" < 0 THEN 'Extreme Cold'
        WHEN "wc" BETWEEN 0 AND 32 THEN 'Chilly'
        ELSE 'Not Chilly'
    END AS wind_chill_status,
    "wx_phrase",
    "valid_date_time"
FROM 
    chicago_weather;

""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
#.142 seconds
#.299 seconds
"""{
"_id":0,
"Unnamed: 0": 1,
"valid_time_gmt": 1,
"wdir": 1,
"wx_phrase": 1,
"valid_date_time": 1,
"opposite_wdir": { "$add": ["$wdir", 180] },
"reduced_wind_chill": { "$subtract": ["$wc", 5] },
"wind_temperature_factor": { "$multiply": ["$temp", "$wspd"] },
"comfort_index": { "$divide": [{ "$add": ["$temp", "$wspd"] }, 2] },
  "comfort_status": {
    "$switch": {
      "branches": [
        {
          "case": {
            "$gt": ["$temp", 85]
          },
          "then": "Too Hot"
        },
        {
          "case": {
            "$lt": ["$temp", 32]
          },
          "then": "Too Cold"
        }
      ],
      "default": "Comfortable"
    }
  },
  "wind_chill_status": {
    "$switch": {
      "branches": [
        {
          "case": {
            "$lt": ["$wc", 0]
          },
          "then": "Extreme Cold"
        },
        {
          "case": {
            "$and": [
              {
                "$gte": ["$wc", 0]
              },
              {
                "$lte": ["$wc", 32]
              }
            ]
          },
          "then": "Chilly"
        }
      ],
      "default": "Not Chilly"
    }
  }
}"""
# Out:
#         Unnamed: 0  valid_time_gmt  opposite_wdir  reduced_wind_chill  \
# 0                0      1072936380          190.0                -6.0
# 1                1      1072939980          200.0                -9.0
# 2                2      1072943580            NaN                -6.0
# 3                3      1072947180          270.0                -8.0
# 4                4      1072950780          290.0                -6.0
# ...            ...             ...            ...                 ...
# 194326      194326      1672451580          440.0                -3.0
# 194327      194327      1672455180          480.0                -6.0
# 194328      194328      1672458780          480.0                -8.0
# 194329      194329      1672462380          480.0                -8.0
# 194330      194330      1672465980            NaN                -6.0
#
#         wind_temperature_factor  comfort_index comfort_status  \
# 0                          -6.0            2.5       Too Cold
# ...

# %% [markdown]
# <h2> 4.2.1 COUNT </h2>

# %%
start_time = time.time()

query = text("""
SELECT 
    COUNT(*) AS Total_Observations,
    COUNT(CASE WHEN wx_phrase = 'Mostly Cloudy' THEN 1 END) AS Mostly_Cloudy_Count,
    COUNT(CASE WHEN temp < 0 THEN 1 END) AS Below_Zero_Count,
    COUNT(CASE WHEN wspd >= 10 THEN 1 END) AS Windy_Conditions_Count,
    COUNT(CASE WHEN vis > 10 THEN 1 END) AS Good_Visibility_Count
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.2f} seconds")
#.159, .003
# Out:
#    total_observations  mostly_cloudy_count  below_zero_count  \
# 0              194331                41577             35342
#
#    windy_conditions_count  good_visibility_count
# 0                  145762                 158749
# Execution Time: 0.03 seconds

# %% [markdown]
# <h2> 4.2.2 SUM </h2>

# %%
start_time = time.time()

query = text("""
SELECT 
    SUM("wspd") AS Total_Wind_Speed,
    SUM(CASE WHEN "temp" < 0 THEN "wspd" ELSE 0 END) AS Sum_Wind_Speed_Below_Zero
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.3f} seconds")
#.159, .003
# Out:
#    total_wind_speed  sum_wind_speed_below_zero
# 0         3122962.0                   607291.0
# Execution Time: 0.023 seconds

# %% [markdown]
# <h1> 4.2.3 MIN </h1>

# %%
start_time = time.time()

query = text("""
SELECT 
    MIN("wspd") AS Min_Wind_Speed,
    MIN("vis") AS Min_Visibility
FROM 
    chicago_weather;
""")

# Execute the query and store the result in a Pandas DataFrame
df = pd.read_sql_query(query, engine)

end_time = time.time()
execution_time = end_time - start_time

# Print the DataFrame
display(df)

print(f"Execution Time: {execution_time:.3f} seconds")
# Out:
#    min_wind_speed  min_visibility
# 0             0.0             0.0
# Execution Time: 0.021 seconds
